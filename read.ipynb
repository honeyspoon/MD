# %%
from cffi import FFI

ffi = FFI()

ffi.cdef("""
#include "src/ouch.h"
""")
# Out:
# ---------------------------------------------------------------------------
# ParseError                                Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/cffi/cparser.py:336, in Parser._parse(self, csource)
#     335 try:
# --> 336     ast = _get_parser().parse(fullcsource)
#     337 except pycparser.c_parser.ParseError as e:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/pycparser/c_parser.py:147, in CParser.parse(self, text, filename, debug)
#     146 self._last_yielded_token = None
# --> 147 return self.cparser.parse(
#     148         input=text,
#     149         lexer=self.clex,
#     150         debug=debug)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/pycparser/ply/yacc.py:331, in LRParser.parse(self, input, lexer, debug, tracking, tokenfunc)
#     330 else:
# --> 331     return self.parseopt_notrack(input, lexer, debug, tracking, tokenfunc)
#
# ...

# %%
import pycstruct

definitions = pycstruct.parse_file('src/ouch.h')
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/pycstruct/cparser.py:60, in _run_castxml(input_files, xml_filename, castxml_cmd, castxml_extra_args, **subprocess_kwargs)
#      59 try:
# ---> 60     output = subprocess.check_output(args, **subprocess_kwargs)
#      61 except subprocess.CalledProcessError as exception:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/subprocess.py:421, in check_output(timeout, *popenargs, **kwargs)
#     419     kwargs['input'] = empty
# --> 421 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     422            **kwargs).stdout
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     525     if check and retcode:
# ...

# %%
from pycparser import parse_file

ast = parse_file(use_cpp=True, filename='src/ouch.h')
# Out:
# ---------------------------------------------------------------------------
# ParseError                                Traceback (most recent call last)
# Cell In[43], line 3
#       1 from pycparser import parse_file
# ----> 3 ast = parse_file(use_cpp=True, filename='src/ouch.h')
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/pycparser/__init__.py:90, in parse_file(filename, use_cpp, cpp_path, cpp_args, parser)
#      88 if parser is None:
#      89     parser = CParser()
# ---> 90 return parser.parse(text, filename)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/pycparser/c_parser.py:147, in CParser.parse(self, text, filename, debug)
#     145 self._scope_stack = [dict()]
#     146 self._last_yielded_token = None
# --> 147 return self.cparser.parse(
#     148         input=text,
#     149         lexer=self.clex,
#     150         debug=debug)
#
# ...
